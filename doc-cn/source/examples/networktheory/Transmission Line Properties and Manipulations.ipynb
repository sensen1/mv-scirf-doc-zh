# %% [markdown]
# # 建模传输线特性## 目录* [简介](#introduction) * [传播常数](#propagation_constant) * [关于衰减单位的补充](#attenuation_units)* [使用传输线函数建模带负载的损耗传输线](#tline_functions) * [输入阻抗、反射系数和驻波比](#tline_impedances) * [电压和电流](#voltages_currents)* [通过串联网络建模带负载的损耗传输线](#cascading_networks)* [根据输入阻抗确定传播常数](#propagation_constant_from_zin)## 简介 <a class="anchor" id="introduction"></a>在本教程中，我们将使用 `scikit-rf` 来处理一些经典的传输线场景，例如计算阻抗、反射系数、驻波比或电压和电流。至少有两种方法可以执行这些计算，一种是使用 [传输线函数](#tline_functions)，另一种是通过 [创建和串联网络](#cascading_networks)。让我们考虑一根具有 $Z_0=75 \Omega$ 特性阻抗和 $d=12 m$ 长度的损耗同轴电缆。该同轴电缆的衰减为 0.02 Neper/m，[速度因子](https://en.wikipedia.org/wiki/Velocity_factor) VF=0.67（大致对应于 [RG-6](https://en.wikipedia.org/wiki/RG-6) 同轴电缆）。电缆上负载了一个 $Z_L=150 \Omega$ 阻抗。感兴趣的射频频率为 250 MHz。请注意，在 `scikit-rf` 中，线路长度是从负载开始定义的，即在负载处 $z=0$，在传输线的输入端 $z=d$：<img src="transmission_line_properties.svg">首先，让我们进行必要的 Python 导入语句：

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import skrf as rf
from skrf.constants import c
from skrf.mathFunctions import db_2_np, db_per_100feet_2_db_per_100meter, feet_2_meter, mag_2_db10, np_2_db
from skrf.tlineFunctions import (
    reflection_coefficient_2_propagation_constant,
    voltage_current_propagation,
    zl_2_Gamma0,
    zl_2_Gamma_in,
    zl_2_swr,
    zl_2_total_loss,
    zl_2_zin,
)

# %%
# skrf figure styling
rf.stylely()

# %% [markdown]
# 以及问题中的常数：

# %%
freq = rf.Frequency(250, npoints=1, unit='MHz')
Z_0 = 75  # Ohm
Z_L = 150  # Ohm
d = 12  # m
VF = 0.67
att = 0.02 # Np/m. Equivalent to 0.1737 dB/m

# %% [markdown]
# 在进行阻抗和反射系数计算之前，我们首先需要定义传输线的特性，特别是其传播常数。

# %% [markdown]
# ### 传播常数为了获得传输线的射频参数，有必要推导出该线的传播常数。在 `scikit-rf` 中，该线的传播常数 $\gamma$ 定义为 $\gamma=\alpha + j\beta$，其中 $\alpha$ 是衰减（单位为奈珀/米），$\beta=\frac{2\pi}{\lambda}=\frac{\omega}{c}/\mathrm{VF}=\frac{\omega}{c}\sqrt{\epsilon_r}$ 是相位常数。首先，同轴电缆中的波长为 $$\lambda=\frac{c}{f \sqrt{\epsilon_r}}=\frac{c}{f} \mathrm{VF} $$

# %%
lambd = c/freq.f * VF
print('VF=', VF, 'and Wavelength:', lambd, 'm')

# %% [markdown]
# 由于衰减已经以 Np/m 的单位给出，因此传播常数为：

# %%
alpha = att  # Np/m !
beta = freq.w/c/VF
gamma = alpha + 1j*beta
print('Transmission line propagation constant: gamma = ', gamma, 'rad/m')

# %% [markdown]
# 如果衰减是以其他单位给出的，`scikit-rf` 提供了必要的工具来进行单位转换，具体如下所述。

# %% [markdown]
# ### 间场：关于衰减单位的说明

# %% [markdown]
# 衰减通常以各种不同的单位表示（或预期）。`scikit-rf` 提供了方便的函数来处理线路衰减单位。例如，以 Np/m 为单位给出的电缆衰减，可以转换为 dB：

# %%
print('Attenuation dB/m:', np_2_db(att))

# %% [markdown]
# 因此，以 dB/100m 为单位的衰减为：

# %%
print('Line attenuation in dB/100m:', np_2_db(att)*100)

# %% [markdown]
# 单位为 dB/100 英尺时：

# %%
print('Line attenuation in dB/100ft:', np_2_db(att)*100*feet_2_meter())

# %% [markdown]
# 如果衰减以英制单位给出，例如 dB/100 英尺，那么相应的换算关系将是：

# %%
db_per_100feet_2_db_per_100meter(5.2949)  # to dB/100m

# %%
db_2_np(5.2949)/feet_2_meter(100)  # to Np/m

# %% [markdown]
# ## 使用传输线函数 <a class="anchor" id="tline_functions"></a>`scikit-rf` 提供了几个方便的函数，用于处理传输线。这些函数在 [传输线函数](../../api/tlineFunctions.rst) 文档页面中有详细介绍。### 输入阻抗、反射系数和驻波比 <a class="anchor" id="tline_impedances"></a>由负载引起的反射系数 $\Gamma_L$ 由 `zl_2_Gamma0()` 函数给出：

# %%
Gamma0 = zl_2_Gamma0(Z_0, Z_L)
print('|Gamma0|=', abs(Gamma0))

# %% [markdown]
# 并且，其相关的驻波比（SWR）可以通过 `zl_2_swr()` 函数获得：

# %%
zl_2_swr(Z_0, Z_L)

# %% [markdown]
# 在具有传播常数 $\gamma$ 的传输线上，信号传播了距离 $d$（因此产生了电长度 $\theta = \gamma d$），可以通过 `zl_2_Gamma_in()` 获得线路输入端的反射系数：

# %%
Gamma_in = zl_2_Gamma_in(Z_0, Z_L, theta=gamma*d)
print('|Gamma_in|=', abs(Gamma_in), 'phase=', 180/np.pi*np.angle(Gamma_in))

# %% [markdown]
# `zl_2_zin()` 函数计算出的输入阻抗 $Z_{in}$：

# %%
Z_in = zl_2_zin(Z_0, Z_L, gamma * d)
print('Input impedance Z_in=', Z_in)

# %% [markdown]
# 和之前一样，线路输入的驻波比为：

# %%
zl_2_swr(Z_0, Z_in)

# %% [markdown]
# 总线路损耗（单位：dB）可以通过 `zl_2_total_loss()` 函数获得：

# %%
mag_2_db10(zl_2_total_loss(Z_0, Z_L, gamma*d))

# %% [markdown]
# ### 电压和电流

# %% [markdown]
# 现在，假设之前的电路由一个电压源激励，该电压源的电压为 $V=1 V$，并且与源阻抗 $Z_s=100\Omega$ 相关联：<img src="transmission_line_properties_vi.svg">

# %%
Z_s = 100  # Ohm
V_s = 1  # V

# %% [markdown]
# 在传输线的输入端，电压是一个分压电路：$$V_{in} = V_s  \frac{Z_{in}}{Z_s + Z_{in}}$$

# %%
V_in = V_s * Z_in / (Z_s + Z_in)
print('Voltage at transmission line input : V_in = ', V_in, ' V')

# %% [markdown]
# 传输线的输入端的电流为：$$I_{in} = \frac{V_s}{Z_s + Z_{in}}$$

# %%
I_in = V_s / (Z_s + Z_in)
print('Current at transmission line input : I_in = ', I_in, ' A')

# %% [markdown]
# 它表示一个功率，公式如下：$$P_{in} = \frac{1}{2} \Re \left[V_{in} I_{in}^* \right]$$

# %%
P_in = 1/2 * np.real(V_in * np.conj(I_in))
print('Input Power : P_in = ', P_in, 'W')

# %% [markdown]
# 反射功率为：$$P_r = |\Gamma_{in}|^2 P_{in}$$

# %%
P_r = abs(Gamma_in)**2 * P_in
print('Reflected power : P_r = ', P_r, 'W')

# %% [markdown]
# 对于长度为 $L$ 的传输线，可以通过其 ABCD 参数推导出负载端的电压和电流：

# %%
V_out, I_out = voltage_current_propagation(V_in, I_in, Z_0,theta= gamma*d)
print('Voltage at load: V_out = ', V_out, 'V')
print('Current at load: I_out = ', I_out, 'A')

# %% [markdown]
# 请注意，电压和电流都以峰值表示。因此，均方根值为：

# %%
print(abs(V_out)/np.sqrt(2), abs(I_out)/np.sqrt(2))

# %% [markdown]
# 因此，传递到负载上的功率为：

# %%
P_out = 1/2 * np.real(V_out * np.conj(I_out))
print('Power delivered to the load : P_out = ', P_out, ' W')

# %% [markdown]
# 以下图表显示了电压和电流与传输线长度的关系（请注意电压和电流传播中 $d$ 的符号：当我们从源端（$z=d$）移动到负载端（$z=0$）时，$\theta$ 的方向相反，因此应该进行反转）。

# %%
ds = np.linspace(0, d, num=1001)

thetas = - gamma*ds

v1 = np.full_like(ds, V_in)
i1 = np.full_like(ds, I_in)

v2, i2 = voltage_current_propagation(v1, i1, Z_0, thetas)

# %%
fig, (ax_V, ax_I) = plt.subplots(2, 1, sharex=True)
ax_V.plot(ds, abs(v2), lw=2)
ax_I.plot(ds, abs(i2), lw=2, c='C1')
ax_I.set_xlabel('z [m]')
ax_V.set_ylabel('|V| [V]')
ax_I.set_ylabel('|I| [A]')


ax_V.axvline(0, c='k', lw=5)
ax_I.axvline(0, c='k', lw=5)
ax_V.text(d-2, 0.4, 'input')
ax_V.text(1, 0.6, 'load')
ax_V.axvline(d, c='k', lw=5)
ax_I.axvline(d, c='k', lw=5)

ax_I.set_title('Current')
ax_V.set_title('Voltage')

# %% [markdown]
# ## 使用 `media` 对象进行传输线计算。

# %% [markdown]
# `scikit-rf` 还提供了表示传输线介质的对象。`Media` 对象提供了通用的方法，可以为任何传输线介质生成网络对象，例如传输线长度（`line()`）、集总元件（`resistor()`、`capacitor()`、`inductor()`、`shunt()` 等）或终端元件（`open()`、`short()`、`load()`）。有关更多参考信息，请参阅[介质文档](../../api/media/index.rst)。让我们为具有特性阻抗 $Z_0$ 和传播常数 $\gamma$ 的同轴线创建一个传输线 `media` 对象：

# %%
# if not passing the gamma parameter, it would assume that gamma = alpha + j*beta = 0 + j*1
coax_line = rf.media.DefinedGammaZ0(frequency=freq, z0=Z_0, gamma=gamma)

# %% [markdown]
# 为了构建如图所示的电路，首先创建所有电路的网络，然后使用 `**` 运算符将它们串联：<img src="transmission_line_properties_networks.svg">* 一个长度为 $d$ 的 [传输线](../../api/media/generated/skrf.media.Media.line.rst)（来自上面创建的介质），* 一个阻抗为 $Z_L$ 的 [电阻器](../../api/media/generated/skrf.media.Media.resistor.rst)，* 然后连接到一个 [短路](../../api/media/generated/skrf.media.Media.short.rst)。这样就形成了一个单端口网络，其 $Z$ 参数就是输入阻抗。

# %%
ntw = coax_line.line(d, unit='m') ** coax_line.resistor(Z_L) ** coax_line.short()
ntw.z

# %% [markdown]
# 请注意，可以使用便捷函数 [load](../../api/media/generated/skrf.media.Media.load.rst) 构建完整的网络模型。

# %%
ntw = coax_line.line(d, unit='m') ** coax_line.load(zl_2_Gamma0(Z_0, Z_L))
ntw.z

# %% [markdown]
# 或者更直接地使用 `delay_load`：

# %%
ntw = coax_line.delay_load(zl_2_Gamma0(Z_0, Z_L), d, unit='m')
ntw.z

# %% [markdown]
# ## 从输入阻抗确定传播常数 <a class="anchor" id="propagation_constant_from_zin"></a>假设我们测量了一条长度为 d=1.5 米，特性阻抗为 $Z_0$=100 欧姆的短路有损传输线的输入阻抗，结果为 $Z_{in}=40 - 280j \Omega$。<img src="transmission_line_properties_propagation_constant.svg">传输线的传播常数 $\gamma$ 是未知的，我们需要研究如何使用 `scikit-rf` 推导出其值：

# %%
# input data
z_in = 20 - 140j
z_0 = 75
d = 1.5
Gamma_load = -1 # short

# %% [markdown]
# 由于我们知道输入阻抗，因此可以推导出传输线输入的反射系数。由于负载端和线路输入端的反射系数之间存在方向关系：$$\Gamma_{in} = \Gamma_L e^{- 2 \gamma d}$$因此，我们可以推导出传播常数值 $\gamma$，如下所示：$$\gamma = -\frac{1}{2d} \ln \left( \frac{\Gamma_{in}}{\Gamma_l} \right)$$这就是便捷函数 `reflection_coefficient_2_propagation_constant` 所做的事情。

# %%
# reflection coefficient at input
Gamma_in = zl_2_Gamma0(z_0, z_in)
# line propagation constant
gamma = reflection_coefficient_2_propagation_constant(Gamma_in, Gamma_load, d)
print('Line propagation constant, gamma =', gamma, 'rad/m')

# %% [markdown]
# 可以通过进行反向计算来检查结果的一致性：计算负载 $Z_l$ 处距离 $d$ 处的输入阻抗。

# %%
zl_2_zin(z_0, zl=0, theta=gamma * d)

# %% [markdown]
# 这实际上就是示例中给定的输入值。

# %% [markdown]
# 现在已经确定了线路的传播常数，就可以用负载电阻来代替短路：

# %%
zl_2_zin(z_0, zl=50+50j, theta=gamma * d)
