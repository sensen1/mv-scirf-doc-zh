# %% [markdown]
# # 排序网络集合

# %% [markdown]
# 通常，在改变某个其他变量（例如电压、电流或时间）时，会记录一组 `Networks`。因此……现在你有了这组数据，并且想查看某个特征是如何演变的，或者计算一些具有代表性的统计数据。本示例演示了如何使用 [NetworkSets](../../tutorials/NetworkSet.ipynb) 来实现这一点。

# %% [markdown]
# ## 生成一些数据

# %% [markdown]
# 为了演示，我们使用预定义的 `skrf.media.Media` 对象生成一些网络，并将它们保存为一系列的 Touchstone 文件。每个文件都以时间戳命名，时间戳由便捷函数 `rf.util.now_string()` 生成。

# %%
from time import sleep

import matplotlib.pyplot as plt
import numpy as np

import skrf as rf
from skrf.util import now_string, now_string_2_dt

# %matplotlib inline
rf.stylely()


# !rm -rf tmp
# !mkdir tmp

wg = rf.instances.wr10 # just a dummy media object to generate data

for k in range(10):
    # timestamp generated with `now_string()`
    ntwk = wg.random(name=now_string()+'.s1p')
    ntwk.s = k*ntwk.s
    ntwk.write_touchstone(dir='tmp')
    sleep(.1)

# %% [markdown]
# 让我们看看我们做了什么。

# %%
# !ls tmp

# %% [markdown]
# ## 未排序（默认）

# %% [markdown]
# 当使用 `NetworkSet.from_dir()` 创建时，`NetworkSet` 会随机存储每个 `Network`。

# %%
ns = rf.networkSet.NetworkSet.from_dir('tmp')
ns.ntwk_set

# %% [markdown]
# ## 排序

# %%
ns.sort()
ns.ntwk_set

# %% [markdown]
# ## 使用 `key` 参数进行排序

# %% [markdown]
# 您还可以通过 `key` 参数传递一个函数，从而允许您根据任意属性进行排序。例如，我们可以根据名称中的秒以下的小数部分进行排序。

# %%
ns = rf.networkSet.NetworkSet.from_dir('tmp')
ns.sort(key = lambda x: x.name.split('.')[0])
ns.ntwk_set

# %% [markdown]
# ## 提取日期时间信息

# %% [markdown]
# 你还可以将 ntwk 名称转换为 datetime 对象，以便你使用 pandas 绘制图形或进行其他处理。`rf.util.now_string()` 还有一个配套函数，即 `rf.util.now_string_2_dt()`。这真是个好主意……

# %%
ns.sort()
dt_idx = [now_string_2_dt(k.name ) for k in ns]
dt_idx

# %% [markdown]
# ## 放入 Pandas DataFrame 并绘制图表

# %% [markdown]
# 下一步是将网络集沿着时间轴进行切片。例如，我们可能想查看几个不同频率下的S11相位。这可以通过以下脚本来实现。请注意，与网络一样，网络集也可以通过人类可读的字符串按频率进行切片。

# %%
import pandas as pd

dates = pd.DatetimeIndex(dt_idx)

# create a function to pull out S11 in degrees at a specific frequency

s_deg_at = lambda s:{s: [k[s].s_deg[0,0,0] for k in ns]}  # noqa: E731

for f in ['80ghz', '90ghz','100ghz']:
    df =pd.DataFrame(s_deg_at(f), index=dates)
    df.plot(ax=plt.gca())
plt.title('Phase Evolution in Time')
plt.ylabel('S11 (deg)')

# %% [markdown]
# ## 使用 `signature` 可视化行为

# %% [markdown]
# 可视化网络参数集在所有频率上的标量分量演变过程可能是有用的。这可以通过进行一些数组操作和使用 `imshow` 来实现。例如，如果我们对每个网络参数取其 dB 值的模，并将其转换为二维矩阵，就可以实现这个目标。

# %%
mat = np.array([k.s_db.flatten() for k in ns])
mat.shape

# %% [markdown]
# 这个数组的形状为（“网络数量”，“频率点数量”）。可以使用 imshow 进行可视化。下面的大部分代码只是添加标签和调整坐标轴的刻度。

# %%
freq = ns[0].frequency

# creates x and y scales
extent = [freq.f_scaled[0], freq.f_scaled[-1], len(ns) ,0]

#make the image
plt.imshow(mat, aspect='auto',extent=extent,interpolation='nearest')

# label things
plt.grid(0)
freq.labelXAxis()
plt.ylabel('Network #')
cbar = plt.colorbar()
cbar.set_label('Magnitude (dB)')

# %% [markdown]
# 这个过程可以通过 `NetworkSet.signature()` 方法自动完成。它甚至有一个 `vs_time` 参数，如果网络对象的名称是由 `rf.now_string()` 写入的，该参数将自动创建 DateTime 索引。

# %%
ns.signature(component='s_db', vs_time=True,cbar_label='Magnitude (dB)')
