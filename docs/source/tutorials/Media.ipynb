# %% [raw]
# .. _media:
#
# |
# |
#
# 下载本 Notebook: :download:`Media.ipynb`

# %% [markdown]
# # 介质

# %% [markdown]
# 本教程介绍 `Media` 对象，用于定义传输线介质。

# %% [markdown]
# ## 导入

# %%
import skrf as rf
import matplotlib.pyplot as plt

# %% [markdown]
# ## 创建介质

# %% [markdown]
# 定义传输线介质。

# %%
# 示例代码
pass

# %% [markdown]
# ## 生成网络

# %% [markdown]
# 从介质生成传输线网络。

# %%
# 示例代码
pass

# %% [markdown]
# ## 不连续性

# %% [markdown]
# 建模传输线不连续性。

# %%
# 示例代码
pass

# %% [markdown]
# ## 结论

# %% [markdown]
# 本教程介绍了 介质 的基本用法。更多详细信息请参阅 API 文档。
