# %% [raw]
# .. _connecting_networks:
#
# |
# |
#
# 下载本 Notebook: :download:`Connecting_Networks.ipynb`

# %% [markdown]
# # 连接网络

# %% [markdown]
# 本教程介绍如何在 `skrf` 中级联和连接网络。

# %% [markdown]
# ## 导入

# %%
import skrf as rf
import matplotlib.pyplot as plt

# %% [markdown]
# ## 级联网络

# %% [markdown]
# 使用 `**` 运算符级联网络。

# %%
# 示例代码
pass

# %% [markdown]
# ## 去嵌入

# %% [markdown]
# 使用 `.inv` 属性进行去嵌入。

# %%
# 示例代码
pass

# %% [markdown]
# ## 多端口连接

# %% [markdown]
# 使用 `connect()` 函数连接多端口网络。

# %%
# 示例代码
pass

# %% [markdown]
# ## 结论

# %% [markdown]
# 本教程介绍了 连接网络 的基本用法。更多详细信息请参阅 API 文档。
