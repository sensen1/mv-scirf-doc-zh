# %% [raw]
# .. _deembedding:
#
# |
# |
#
# 下载本 Notebook: :download:`Deembedding.ipynb`

# %% [markdown]
# # 去嵌入

# %% [markdown]
# 本教程介绍去嵌入技术，用于去除夹具和连接器的影响。

# %% [markdown]
# ## 导入

# %%
import skrf as rf
import matplotlib.pyplot as plt

# %% [markdown]
# ## 去嵌入类型

# %% [markdown]
# 介绍各种去嵌入算法。

# %%
# 示例代码
pass

# %% [markdown]
# ## 2x-Thru 方法

# %% [markdown]
# 使用 2x-Thru 方法进行去嵌入。

# %%
# 示例代码
pass

# %% [markdown]
# ## 应用

# %% [markdown]
# 将去嵌入应用于测量数据。

# %%
# 示例代码
pass

# %% [markdown]
# ## 结论

# %% [markdown]
# 本教程介绍了 去嵌入 的基本用法。更多详细信息请参阅 API 文档。
